# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

# %%
df = pd.read_csv("BI_noB1B10_2017_test_pixel.csv")
df.head()
# Out:
#    ID Region tillClass  B10_p0_sow  B10_p100_sow  B10_p25_sow  B10_p50_sow  \
# 0   1  Bihar        ZT   -0.924913      3.029043    -0.723106    -0.209337
# 1   1  Bihar        ZT   -1.041067      0.380373    -0.790673    -0.597369
# 2   1  Bihar        ZT   -0.924913      3.029043    -0.723106    -0.209337
# 3   1  Bihar        ZT   -0.924913     11.459722    -0.723106    -0.018267
# 4   1  Bihar        ZT   -0.924913      3.029043    -0.723106    -0.209337
#
#    B10_p75_sow  B11_p0_sow  B11_p100_sow  ...  SNDVI_p0_peak  SNDVI_p100_peak  \
# 0     0.380373    0.124338      0.285878  ...       0.109090         0.492909
# 1     0.137131    0.143189      0.301672  ...       0.132488         0.603815
# 2     0.380373    0.131779      0.286525  ...       0.110585         0.460611
# 3     0.427072    0.133647      0.407353  ...       0.105139         0.458611
# 4     0.380373    0.124338      0.285878  ...       0.099935         0.459526
#
# ...

# %%
X = df.drop(['Region'], axis='columns')
selected_features = ['NDVI_p50_sow','SNDVI_p50_sow','CRC_p50_sow','GCVI_p50_sow']
X = df[selected_features]
y = df['NDTI_p50_sow']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
model = RandomForestRegressor(n_estimators=600)
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=600)

# %%
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

y_pred = model.predict(X_test)

r2 = r2_score(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))  # <-- manual RMSE

print("R² Score:", r2)
print("RMSE:", rmse)
# Out:
# R² Score: 0.7276448535938156
# RMSE: 0.02688980571266113

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,6))
plt.scatter(y_test, y_pred, alpha=0.5)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--') # 1:1 line
plt.xlabel("Actual NDTI")
plt.ylabel("Predicted NDTI")
plt.title("Predicted vs Actual NDTI")
plt.grid(True)
plt.show()
